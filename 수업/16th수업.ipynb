# %%
import pandas as pd

# %%
A = pd.DataFrame({"sal": [1200, 1600, 5600, 6000, 7000]})

# %%
A.mean()
# Out:
# sal    4280.0
# dtype: float64

# %%
A
# Out:
#     sal
# 0  1200
# 1  1600
# 2  5600
# 3  6000
# 4  7000

# %%
B = pd.DataFrame({"sal":[4000, 4500, 4250, 5000, 3650]})

# %%
A - A.mean()
# Out:
#       sal
# 0 -3080.0
# 1 -2680.0
# 2  1320.0
# 3  1720.0
# 4  2720.0

# %%
B - B.mean()
# Out:
#      sal
# 0 -280.0
# 1  220.0
# 2  -30.0
# 3  720.0
# 4 -630.0

# %%
(A - A.mean()) ** 2
# Out:
#          sal
# 0  9486400.0
# 1  7182400.0
# 2  1742400.0
# 3  2958400.0
# 4  7398400.0

# %%
import math

# %%
((A - A.mean()) ** 2).sum()
# Out:
# sal    28768000.0
# dtype: float64

# %%
(B - B.mean()) ** 2
# Out:
#         sal
# 0   78400.0
# 1   48400.0
# 2     900.0
# 3  518400.0
# 4  396900.0

# %%
(((B - B.mean()) ** 2)).sum()
# Out:
# sal    1043000.0
# dtype: float64

# %%
((A - A.mean()) ** 2).sum() / 4
# Out:
# sal    7192000.0
# dtype: float64

# %%
(((B - B.mean()) ** 2)).sum() / 4
# Out:
# sal    260750.0
# dtype: float64

# %%
A.var()
# Out:
# sal    7192000.0
# dtype: float64

# %%
B.var()
# Out:
# sal    260750.0
# dtype: float64

# %%
math.sqrt(((A - A.mean()) ** 2).sum() / 4)
# Out:
# 2681.790446697877

# %%
math.sqrt((((B - B.mean()) ** 2)).sum() / 4)
# Out:
# 510.63685726747144

# %%
A.std()
# Out:
# sal    2681.790447
# dtype: float64

# %%
B.std()
# Out:
# sal    510.636857
# dtype: float64

# %%
df01 = pd.DataFrame({"eng_rank":[1, 4, 2, 9, 9], "kor_rank":[3, 2, 7, 3, 10]})

# %%
df01["eng_rank"].mean()
# Out:
# 5.0

# %%
df01.mean()
# Out:
# eng_rank    5.0
# kor_rank    5.0
# dtype: float64

# %%
df01.cov()
# Out:
#           eng_rank  kor_rank
# eng_rank     14.50      4.25
# kor_rank      4.25     11.50

# %%
df = pd.read_csv("auto-mpg.csv")

# %%
df.columns = ["mpg", "cylinders", "displacement", "horesepower", "weight", "acceleration", "model year", "origin", "name"]

# %%
df
# Out:
#       mpg  cylinders  displacement horesepower  weight  acceleration  \
# 0    15.0          8         350.0       165.0  3693.0          11.5
# 1    18.0          8         318.0       150.0  3436.0          11.0
# 2    16.0          8         304.0       150.0  3433.0          12.0
# 3    17.0          8         302.0       140.0  3449.0          10.5
# 4    15.0          8         429.0       198.0  4341.0          10.0
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         140.0       86.00  2790.0          15.6
# 393  44.0          4          97.0       52.00  2130.0          24.6
# 394  32.0          4         135.0       84.00  2295.0          11.6
# 395  28.0          4         120.0       79.00  2625.0          18.6
# 396  31.0          4         119.0       82.00  2720.0          19.4
#
#      model year  origin                name
# 0            70       1   buick skylark 320
# 1            70       1  plymouth satellite
# ...

# %%
df.corr()["mpg"]
# Out:
# mpg             1.000000
# cylinders      -0.775412
# displacement   -0.803972
# weight         -0.831558
# acceleration    0.419133
# model year      0.578667
# origin          0.562894
# Name: mpg, dtype: float64

# %%
df[["mpg", "origin", "name"]]
# Out:
#       mpg  origin                name
# 0    15.0       1   buick skylark 320
# 1    18.0       1  plymouth satellite
# 2    16.0       1       amc rebel sst
# 3    17.0       1         ford torino
# 4    15.0       1    ford galaxie 500
# ..    ...     ...                 ...
# 392  27.0       1     ford mustang gl
# 393  44.0       2           vw pickup
# 394  32.0       1       dodge rampage
# 395  28.0       1         ford ranger
# 396  31.0       1          chevy s-10
#
# [397 rows x 3 columns]

# %%
df[["mpg", "origin", "name"]].corr()
# Out:
#              mpg    origin
# mpg     1.000000  0.562894
# origin  0.562894  1.000000

# %%
df = pd.read_excel("남북한발전전력량.xlsx")

# %%
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
df.iloc[[0, 5], : ]
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 5   255   235   237   211   215   221   216   190   239
#
# [2 rows x 29 columns]

# %%
df_ns = df.iloc[[0, 5], 3 : ]

# %%
df_ns.index = ["South", "North"]

# %%
df_ns
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# South  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# North   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
df_ns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, South to North
# Data columns (total 26 columns):
# 1991    2 non-null object
# 1992    2 non-null object
# 1993    2 non-null object
# 1994    2 non-null object
# 1995    2 non-null object
# 1996    2 non-null object
# 1997    2 non-null object
# 1998    2 non-null object
# 1999    2 non-null object
# 2000    2 non-null object
# 2001    2 non-null object
# 2002    2 non-null object
# 2003    2 non-null object
# 2004    2 non-null object
# 2005    2 non-null object
# 2006    2 non-null object
# 2007    2 non-null object
# 2008    2 non-null object
# 2009    2 non-null object
# 2010    2 non-null object
# 2011    2 non-null object
# 2012    2 non-null object
# 2013    2 non-null object
# 2014    2 non-null object
# 2015    2 non-null object
# 2016    2 non-null object
# dtypes: object(26)
# memory usage: 432.0+ bytes

# %%
df_ns["1994"].map(int)
# Out:
# South    1650
# North     231
# Name: 1994, dtype: int64

# %%
df_ns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, South to North
# Data columns (total 26 columns):
# 1991    2 non-null object
# 1992    2 non-null object
# 1993    2 non-null object
# 1994    2 non-null object
# 1995    2 non-null object
# 1996    2 non-null object
# 1997    2 non-null object
# 1998    2 non-null object
# 1999    2 non-null object
# 2000    2 non-null object
# 2001    2 non-null object
# 2002    2 non-null object
# 2003    2 non-null object
# 2004    2 non-null object
# 2005    2 non-null object
# 2006    2 non-null object
# 2007    2 non-null object
# 2008    2 non-null object
# 2009    2 non-null object
# 2010    2 non-null object
# 2011    2 non-null object
# 2012    2 non-null object
# 2013    2 non-null object
# 2014    2 non-null object
# 2015    2 non-null object
# 2016    2 non-null object
# dtypes: object(26)
# memory usage: 512.0+ bytes

# %%
df_ns.columns = df_ns.columns.map(int)

# %%
df_ns.shape
# Out:
# (2, 26)

# %%
df_ns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, South to North
# Data columns (total 26 columns):
# 1991    2 non-null object
# 1992    2 non-null object
# 1993    2 non-null object
# 1994    2 non-null object
# 1995    2 non-null object
# 1996    2 non-null object
# 1997    2 non-null object
# 1998    2 non-null object
# 1999    2 non-null object
# 2000    2 non-null object
# 2001    2 non-null object
# 2002    2 non-null object
# 2003    2 non-null object
# 2004    2 non-null object
# 2005    2 non-null object
# 2006    2 non-null object
# 2007    2 non-null object
# 2008    2 non-null object
# 2009    2 non-null object
# 2010    2 non-null object
# 2011    2 non-null object
# 2012    2 non-null object
# 2013    2 non-null object
# 2014    2 non-null object
# 2015    2 non-null object
# 2016    2 non-null object
# dtypes: object(26)
# memory usage: 512.0+ bytes

# %%
for index in range(df_ns.shape[1]):
    df_ns.iloc[: , index] = df_ns.iloc[: ,index].map(int)

# %%
df_ns
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# South  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# North   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
df_ns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, South to North
# Data columns (total 26 columns):
# 1991    2 non-null int64
# 1992    2 non-null int64
# 1993    2 non-null int64
# 1994    2 non-null int64
# 1995    2 non-null int64
# 1996    2 non-null int64
# 1997    2 non-null int64
# 1998    2 non-null int64
# 1999    2 non-null int64
# 2000    2 non-null int64
# 2001    2 non-null int64
# 2002    2 non-null int64
# 2003    2 non-null int64
# 2004    2 non-null int64
# 2005    2 non-null int64
# 2006    2 non-null int64
# 2007    2 non-null int64
# 2008    2 non-null int64
# 2009    2 non-null int64
# 2010    2 non-null int64
# 2011    2 non-null int64
# 2012    2 non-null int64
# 2013    2 non-null int64
# 2014    2 non-null int64
# 2015    2 non-null int64
# 2016    2 non-null int64
# dtypes: int64(26)
# memory usage: 512.0+ bytes

# %%
df_ns.columns
# Out:
# Int64Index([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#             2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016],
#            dtype='int64')

# %%
df_ns.plot()

# %%
df_ns.T
# Out:
#       South  North
# 1991   1186    263
# 1992   1310    247
# 1993   1444    221
# 1994   1650    231
# 1995   1847    230
# 1996   2055    213
# 1997   2244    193
# 1998   2153    170
# 1999   2393    186
# 2000   2664    194
# 2001   2852    202
# 2002   3065    190
# 2003   3225    196
# 2004   3421    206
# 2005   3646    215
# 2006   3812    225
# 2007   4031    236
# 2008   4224    255
# 2009   4336    235
# 2010   4747    237
# 2011   4969    211
# 2012   5096    215
# 2013   5171    221
# 2014   5220    216
# 2015   5281    190
# 2016   5404    239

# %%
tdf_ns = df_ns.T

# %%
tdf_ns.plot()

# %%
df_ns.plot()

# %%
df01 = pd.DataFrame({
    "A": [100, 200, 200, 100, 500],
    "B": [100, 500, 500, 200, 300]
})

# %%
df01.plot(kind="bar")

# %%
df01.plot(kind="hist")

# %%
df01["A"].plot(kind="hist")

# %%
df01["B"].plot(kind="hist")

# %%
df01
# Out:
#      A    B
# 0  100  100
# 1  200  500
# 2  200  500
# 3  100  200
# 4  500  300

# %%
df01.plot(x="A", y="B", kind="scatter")

# %%
CCTV_Seoul = pd.read_csv("CCTV_in_Seoul.csv", encoding="utf-8")

# %%
CCTV_Seoul
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:"구별"}, inplace = True)

# %%
CCTV_Seoul
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls", encoding="utf-8", header = 2)

# %%
pop_Seoul
# Out:
#           기간   자치구         세대           계         남자         여자        계.1  \
# 0   2017.1/4    합계  4202888.0  10197604.0  5000005.0  5197599.0  9926968.0
# 1   2017.1/4   종로구    72654.0    162820.0    79675.0    83145.0   153589.0
# 2   2017.1/4    중구    59481.0    133240.0    65790.0    67450.0   124312.0
# 3   2017.1/4   용산구   106544.0    244203.0   119132.0   125071.0   229456.0
# 4   2017.1/4   성동구   130868.0    311244.0   153768.0   157476.0   303380.0
# 5   2017.1/4   광진구   158960.0    372164.0   180992.0   191172.0   357211.0
# 6   2017.1/4  동대문구   159839.0    369496.0   182932.0   186564.0   354079.0
# 7   2017.1/4   중랑구   177548.0    414503.0   206102.0   208401.0   409882.0
# 8   2017.1/4   성북구   188512.0    461260.0   224076.0   237184.0   449773.0
# 9   2017.1/4   강북구   141554.0    330192.0   161686.0   168506.0   326686.0
# 10  2017.1/4   도봉구   136613.0    348646.0   171026.0   177620.0   346629.0
# ...

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls", 
                          header = 2,
                          encoding= "utf-8",
                          usecols = "B, D, G, J, N"
                         )

# %%
pop_Seoul
# Out:
#      자치구           계        계.1       계.2   65세이상고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_Seoul.columns
# Out:
# Index(['자치구', '계', '계.1', '계.2', '65세이상고령자'], dtype='object')

# %%
pop_Seoul.columns = ["구별", "인구수", "한국인", "외국인", "고령자"]

# %%
pop_Seoul.columns
# Out:
# Index(['구별', '인구수', '한국인', '외국인', '고령자'], dtype='object')

# %%
pop_Seoul
# Out:
#       구별         인구수        한국인       외국인        고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_Seoul.drop([0], inplace = True)

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul.drop([26], axis = 0, inplace=True)

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul["외국인비율"] = pop_Seoul["외국인"] / pop_Seoul["인구수"] * 100
pop_Seoul["고령자비율"] = pop_Seoul["고령자"] / pop_Seoul["인구수"] * 100

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4    성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5    광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 6   동대문구  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322
# 7    중랑구  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 8    성북구  461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 10   도봉구  348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 11   노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 12   은평구  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797
# ...

# %%
pop_Seoul["외국인비율"].plot(kind="barh")

# %%
pop_Seoul = pop_Seoul.set_index("구별")

# %%
pop_Seoul
# Out:
#            인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 구별
# 종로구   162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 중구    133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 용산구   244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 성동구   311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 광진구   372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 동대문구  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322
# 중랑구   414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 성북구   461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 강북구   330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 도봉구   348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 노원구   569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 은평구   494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797
# 마포구   389649.0  378566.0  11083.0  48765.0  2.844355  12.515110
# ...

# %%
pop_Seoul["외국인비율"].plot(kind="barh")
# Out:
# C:\ai\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ai\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ai\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ai\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ai\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ai\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49328 missing from current font.
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rc("font", family="Malgun Gothic")

# %%
plt.style.use("ggplot")
pop_Seoul["외국인비율"].plot(kind="barh", 
                        color="cornflowerblue", 
                        width = 0.5, 
                        figsize=(30, 20)
                       )

# %%
pop_Seoul.sort_values(by="외국인비율")
# Out:
#            인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 구별
# 도봉구   348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 노원구   569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 양천구   479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 강남구   570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 은평구   494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 강동구   453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# 서초구   450310.0  445994.0   4316.0  51733.0  0.958451  11.488308
# 송파구   667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 강북구   330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 강서구   603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 중랑구   414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 성북구   461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 성동구   311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 마포구   389649.0  378566.0  11083.0  48765.0  2.844355  12.515110
# ...

# %%
pop_Seoul.sort_values(by="외국인비율", ascending="False")
# Out:
#            인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 구별
# 도봉구   348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 노원구   569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 양천구   479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 강남구   570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 은평구   494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 강동구   453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# 서초구   450310.0  445994.0   4316.0  51733.0  0.958451  11.488308
# 송파구   667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 강북구   330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 강서구   603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 중랑구   414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 성북구   461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 성동구   311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 마포구   389649.0  378566.0  11083.0  48765.0  2.844355  12.515110
# ...

# %%
#pop_Seoul.sort_values(by="외국인비율", ascending="False")["외국인비율"]

plt.style.use("ggplot")
pop_Seoul.sort_values(by="외국인비율", ascending="False")["외국인비율"].plot(kind="barh", 
                        color="cornflowerblue", 
                        width = 0.5, 
                        figsize=(10, 5)
                       )

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on="구별")

# %%
data_result
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       인구수       한국인      외국인  \
# 0    강남구  2780       1292    430    584    932  570500.0  565550.0   4950.0
# 1    강동구   773        379     99    155    377  453233.0  449019.0   4214.0
# 2    강북구   748        369    120    138    204  330192.0  326686.0   3506.0
# 3    강서구   884        388    258    184     81  603772.0  597248.0   6524.0
# 4    관악구  1496        846    260    390    613  525515.0  507203.0  18312.0
# 5    광진구   707        573     78     53    174  372164.0  357211.0  14953.0
# 6    구로구  1561       1142    173    246    323  447874.0  416487.0  31387.0
# 7    금천구  1015        674     51    269    354  255082.0  236353.0  18729.0
# 8    노원구  1265        542     57    451    516  569384.0  565565.0   3819.0
# 9    도봉구   485        238    159     42    386  348646.0  346629.0   2017.0
# 10  동대문구  1294       1070     23    198    579  369496.0  354079.0  15417.0
# ...
