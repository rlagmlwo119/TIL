# %%
! pip uninstall -y datascience
# Out:
# WARNING: Skipping datascience as it is not installed.

# %%
! pip uninstall -y branca
# Out:
# WARNING: Skipping branca as it is not installed.

# %%
# !pip install git+https://github.com/python-visualization/branca.git@master
# Out:
# ...
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to c:\users\l13\appdata\local\temp\pip-req-build-2za3ta2s
#   Running command git clone -q https://github.com/python-visualization/branca.git 'C:\Users\L13\AppData\Local\Temp\pip-req-build-2za3ta2s'
#   ERROR: Error [WinError 2] 지정된 파일을 찾을 수 없습니다 while executing command git clone -q https://github.com/python-visualization/branca.git 'C:\Users\L13\AppData\Local\Temp\pip-req-build-2za3ta2s'
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?

# %%
import pandas as pd

# %%
CCTV_Seoul = pd.read_csv("CCTV_in_Seoul.csv", encoding="utf-8")

# %%
CCTV_Seoul
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:"구별"}, inplace=True)

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls", encoding= "utf-8", header=2)

# %%
pop_Seoul
# Out:
#           기간   자치구         세대           계         남자         여자        계.1  \
# 0   2017.1/4    합계  4202888.0  10197604.0  5000005.0  5197599.0  9926968.0
# 1   2017.1/4   종로구    72654.0    162820.0    79675.0    83145.0   153589.0
# 2   2017.1/4    중구    59481.0    133240.0    65790.0    67450.0   124312.0
# 3   2017.1/4   용산구   106544.0    244203.0   119132.0   125071.0   229456.0
# 4   2017.1/4   성동구   130868.0    311244.0   153768.0   157476.0   303380.0
# 5   2017.1/4   광진구   158960.0    372164.0   180992.0   191172.0   357211.0
# 6   2017.1/4  동대문구   159839.0    369496.0   182932.0   186564.0   354079.0
# 7   2017.1/4   중랑구   177548.0    414503.0   206102.0   208401.0   409882.0
# 8   2017.1/4   성북구   188512.0    461260.0   224076.0   237184.0   449773.0
# 9   2017.1/4   강북구   141554.0    330192.0   161686.0   168506.0   326686.0
# 10  2017.1/4   도봉구   136613.0    348646.0   171026.0   177620.0   346629.0
# ...

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls", encoding= "utf-8", header=2, usecols = "B, D, G, J, N")

# %%
pop_Seoul.columns= ["구별", "인구수", "한국인", "외국인", "고령자"]

# %%
pop_Seoul.drop([0], inplace=True)

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul.drop([26], inplace=True)

# %%
pop_Seoul["외국인비율"] = pop_Seoul["외국인"] / pop_Seoul["인구수"] * 100
pop_Seoul["고령자비율"] = pop_Seoul["고령자"] / pop_Seoul["인구수"] * 100

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on="구별")

# %%
data_result.columns.str.contains("년")
# Out:
# array([False, False,  True,  True,  True,  True, False, False, False,
#        False, False, False])

# %%
data_result.columns[data_result.columns.str.contains("년")]
# Out:
# Index(['2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
data_result.drop(data_result.columns[data_result.columns.str.contains("년")],  axis = 1, inplace = True)

# %%
data_result
# Out:
#       구별    소계       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 0    강남구  2780  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 1    강동구   773  453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# 2    강북구   748  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 3    강서구   884  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 4    관악구  1496  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291
# 5    광진구   707  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 6    구로구  1561  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 7    금천구  1015  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 8    노원구  1265  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 9    도봉구   485  348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 10  동대문구  1294  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322
# 11   동작구  1091  412520.0  400456.0  12064.0  56013.0  2.924464  13.578251
# ...

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
plt.rc("font", family="Malgun Gothic")

# %%
data_result.set_index("구별", inplace=True)

# %%
plt.figure(figsize=(10, 10))
data_result["소계"].plot(kind="barh")

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 10))
data_result["소계"].plot(kind="barh", 
                      grid=False)

# %%
data_result["소계"].sort_values()
# Out:
# 구별
# 도봉구      485
# 마포구      574
# 송파구      618
# 중랑구      660
# 중구       671
# 광진구      707
# 강북구      748
# 강동구      773
# 강서구      884
# 영등포구     904
# 서대문구     962
# 종로구     1002
# 금천구     1015
# 성동구     1062
# 동작구     1091
# 노원구     1265
# 동대문구    1294
# 성북구     1464
# 관악구     1496
# 구로구     1561
# 용산구     1624
# 은평구     1873
# 서초구     1930
# 양천구     2034
# 강남구     2780
# Name: 소계, dtype: int64

# %%
plt.style.use("ggplot")
plt.figure(figsize=(10, 10))
data_result["소계"].sort_values().plot(kind="barh", 
                      grid=False,
                    color="cornflowerblue")

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result["인구수"],
           data_result["소계"],
           s = 50,
           color="cornflowerblue")
plt.xlabel("인구수")
plt.ylabel("CCTV")
# Out:
# Text(0, 0.5, 'CCTV')

# %%
A = pd.DataFrame({"공부한시간":[3, 5, 6, 3.5, 4],
            "수학점수": [50, 70, 80, 55, 60]})

# %%
A
# Out:
#    공부한시간  수학점수
# 0    3.0    50
# 1    5.0    70
# 2    6.0    80
# 3    3.5    55
# 4    4.0    60

# %%
import numpy as np

# %%
np.polyfit(A["공부한시간"], A["수학점수"], 1)
# Out:
# array([10., 20.])

# %%
fp1 = np.polyfit(A["공부한시간"], A["수학점수"], 1)

# %%
f1 = np.poly1d(fp1)

# %%
f1
# Out:
# poly1d([10., 20.])

# %%
f1(7)
# Out:
# 89.99999999999999

# %%
B = pd.DataFrame({
    "공부한시간": [3, 5, 6, 3.5, 4], 
    "수학점수": [40, 70 , 50, 55, 20]
})

# %%
B
# Out:
#    공부한시간  수학점수
# 0    3.0    40
# 1    5.0    70
# 2    6.0    50
# 3    3.5    55
# 4    4.0    20

# %%
fp2 = np.polyfit(B["공부한시간"], B["수학점수"], 1)

# %%
fp2
# Out:
# array([ 5.51724138, 23.27586207])

# %%
f2 = np.poly1d(fp2)

# %%
f2(3)
# Out:
# 39.827586206896555

# %%
fp1 = np.polyfit(
data_result["인구수"],
data_result["소계"],
1
)

# %%
f1 = np.poly1d(fp1)

# %%
f1(10000)
# Out:
# 658.158138097162

# %%
fx = np.linspace(10000, 700000, 100)

# %%
len(fx)
# Out:
# 100

# %%
fx
# Out:
# array([ 10000.        ,  16969.6969697 ,  23939.39393939,  30909.09090909,
#         37878.78787879,  44848.48484848,  51818.18181818,  58787.87878788,
#         65757.57575758,  72727.27272727,  79696.96969697,  86666.66666667,
#         93636.36363636, 100606.06060606, 107575.75757576, 114545.45454545,
#        121515.15151515, 128484.84848485, 135454.54545455, 142424.24242424,
#        149393.93939394, 156363.63636364, 163333.33333333, 170303.03030303,
#        177272.72727273, 184242.42424242, 191212.12121212, 198181.81818182,
#        205151.51515152, 212121.21212121, 219090.90909091, 226060.60606061,
#        233030.3030303 , 240000.        , 246969.6969697 , 253939.39393939,
#        260909.09090909, 267878.78787879, 274848.48484848, 281818.18181818,
#        288787.87878788, 295757.57575758, 302727.27272727, 309696.96969697,
#        316666.66666667, 323636.36363636, 330606.06060606, 337575.75757576,
# ...

# %%
f1(fx)
# Out:
# array([ 658.1581381 ,  667.28261551,  676.40709293,  685.53157035,
#         694.65604777,  703.78052519,  712.9050026 ,  722.02948002,
#         731.15395744,  740.27843486,  749.40291227,  758.52738969,
#         767.65186711,  776.77634453,  785.90082195,  795.02529936,
#         804.14977678,  813.2742542 ,  822.39873162,  831.52320903,
#         840.64768645,  849.77216387,  858.89664129,  868.02111871,
#         877.14559612,  886.27007354,  895.39455096,  904.51902838,
#         913.64350579,  922.76798321,  931.89246063,  941.01693805,
#         950.14141547,  959.26589288,  968.3903703 ,  977.51484772,
#         986.63932514,  995.76380255, 1004.88827997, 1014.01275739,
#        1023.13723481, 1032.26171223, 1041.38618964, 1050.51066706,
#        1059.63514448, 1068.7596219 , 1077.88409931, 1087.00857673,
#        1096.13305415, 1105.25753157, 1114.38200899, 1123.5064864 ,
#        1132.63096382, 1141.75544124, 1150.87991866, 1160.00439607,
# ...

# %%
plt.figure(figsize=(10, 10))
plt.scatter(data_result["인구수"], data_result["소계"], s=50, color="cornflowerblue")
plt.plot(fx, f1(fx), ls="dashed", lw=3, color="g")
plt.xlabel("인구수")
plt.ylabel("CCTV")
# Out:
# Text(0, 0.5, 'CCTV')

# %%
df_sort = data_result.sort_values(by="인구수", ascending=False)

# %%
df_sort
# Out:
#         소계       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 구별
# 송파구    618  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 강서구    884  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 강남구   2780  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 노원구   1265  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 관악구   1496  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291
# 은평구   1873  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 양천구   2034  479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 성북구   1464  461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 강동구    773  453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# 서초구   1930  450310.0  445994.0   4316.0  51733.0  0.958451  11.488308
# 구로구   1561  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 중랑구    660  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# ...

# %%
df_sort.index
# Out:
# Index(['송파구', '강서구', '강남구', '노원구', '관악구', '은평구', '양천구', '성북구', '강동구', '서초구',
#        '구로구', '중랑구', '동작구', '영등포구', '마포구', '광진구', '동대문구', '도봉구', '강북구', '서대문구',
#        '성동구', '금천구', '용산구', '종로구', '중구'],
#       dtype='object', name='구별')

# %%
df_sort.index[0]
# Out:
# '송파구'

# %%
plt.figure(figsize=(10, 10))
plt.scatter(data_result["인구수"],
            data_result["소계"],
            s=50,
            color="cornflowerblue")
plt.plot(fx, f1(fx), ls="dashed", lw=3, color="g")
plt.xlabel("인구수")
plt.ylabel("CCTV")
plt.text(df_sort["인구수"][0],
            df_sort["소계"][0],
         df_sort.index[0], fontsize=10)
# Out:
# Text(667483.0, 618, '송파구')

# %%
plt.figure(figsize=(10, 10))
plt.scatter(data_result["인구수"],
            data_result["소계"],
            s=50,
            color="cornflowerblue")
plt.plot(fx, f1(fx), ls="dashed", lw=3, color="g")
plt.xlabel("인구수")
plt.ylabel("CCTV")
plt.text(df_sort["인구수"][0]*1.02,
            df_sort["소계"][0]*0.98,
         df_sort.index[0], fontsize=10)
# Out:
# Text(680832.66, 605.64, '송파구')

# %%
plt.figure(figsize=(10, 10))
plt.scatter(data_result["인구수"],
            data_result["소계"],
            s=50,
            c=data_result["소계"]
            )
plt.plot(fx, f1(fx), ls="dashed", lw=3, color="g")
plt.xlabel("인구수")
plt.ylabel("CCTV")
for n in range(10):
    plt.text(df_sort["인구수"][n]*1.02,
            df_sort["소계"][n]*0.98,
         df_sort.index[n], fontsize=10)

# %%
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %%
plt.figure(figsize=(10, 10))
plt.scatter(data_result["인구수"],
            data_result["소계"],
            s=50,
            c=data_result["소계"]
            )
plt.plot(fx, f1(fx), ls="dashed", lw=3, color="g")
plt.xlabel("인구수")
plt.ylabel("CCTV")
for n in range(10):
    plt.text(df_sort["인구수"][n]*1.02,
            df_sort["소계"][n]*0.98,
         df_sort.index[n], fontsize=10)
plt.colorbar()

# %%
import folium

# %%
folium.Map(location=[37.493747, 127.032690])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(location=[37.493747, 127.032690], zoom_start=16)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_map = folium.Map(location=[37.493747, 127.032690], zoom_start=18)

# %%
seoul_map.save("./seoul.html")

# %%
folium.Map(location=[37.493747, 127.032690],
           zoom_start=16,
           tiles="Stamen Terrain")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(location=[37.493747, 127.032690], zoom_start=18,
           tiles="Stamen Toner")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
marker_map = folium.Map(location=[37.494296, 127.033050],
                        popup="")

# %%
marker_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(location=[37.494296, 127.033050],
             popup = "Star Bucks").add_to(marker_map)

# %%
marker_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker(location=[37.492772, 127.032762],
             radius=10, popup="YeockSam Elementary School",
                    fill=True,
                    fill_color="brown",
                    fill_opacity=0.7,
                   color="brown").add_to(marker_map)

# %%
marker_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json

# %%
import pandas as pd

# %%
pd.read_excel("경기도인구데이터.xlsx")
# Out:
#          구분    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0    수원시장안구  287474  285803  290798  293692  290999  291757  300908  301196
# 1    수원시권선구  310553  308177  304097  306783  321176  332633  331773  339835
# 2    수원시팔달구  216945  213235  219833  216503  209772  206794  204805  203479
# 3    수원시영통구  252730  260210  258421  260557  266542  289074  310671  329718
# 4    성남시수정구  256744  248452  242161  241070  236123  233997  228167  223539
# 5    성남시중원구  263101  265137  259877  258093  254872  253883  256349  251982
# 6    성남시분당구  434115  428858  460688  481027  488328  490735  495018  499087
# 7      의정부시  421853  430849  431008  431801  430400  429147  430976  431112
# 8    안양시만안구  265881  262820  262258  266261  263077  253492  250246  247315
# 9    안양시동안구  358316  357459  354289  355453  352565  357920  357631  353494
# 10   부천시원미구  443290  441795  447136  448602  446247  446604  444207  442638
# ...

# %%
df = pd.read_excel("경기도인구데이터.xlsx", index_col="구분")

# %%
df
# Out:
#            2007    2008    2009    2010    2011    2012    2013    2014  \
# 구분
# 수원시장안구   287474  285803  290798  293692  290999  291757  300908  301196
# 수원시권선구   310553  308177  304097  306783  321176  332633  331773  339835
# 수원시팔달구   216945  213235  219833  216503  209772  206794  204805  203479
# 수원시영통구   252730  260210  258421  260557  266542  289074  310671  329718
# 성남시수정구   256744  248452  242161  241070  236123  233997  228167  223539
# 성남시중원구   263101  265137  259877  258093  254872  253883  256349  251982
# 성남시분당구   434115  428858  460688  481027  488328  490735  495018  499087
# 의정부시     421853  430849  431008  431801  430400  429147  430976  431112
# 안양시만안구   265881  262820  262258  266261  263077  253492  250246  247315
# 안양시동안구   358316  357459  354289  355453  352565  357920  357631  353494
# 부천시원미구   443290  441795  447136  448602  446247  446604  444207  442638
# 부천시소사구   227484  230155  229335  230557  232190  231363  229959  226400
# ...

# %%
json.load(open("경기도행정구역경계.json", encoding="utf-8"))
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'code': 31380,
#     'name': '양평군',
#     'name_eng': 'Yangpyeong-gun',
#     'base_year': 2013},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.56113535909492, 37.6256560539258],
#       [127.57290963929243, 37.61087369350498],
#       [127.56366973908277, 37.5842624297699],
#       [127.52226606559191, 37.5828628697518],
#       [127.50048767007603, 37.569036373178626],
#       [127.47687473909174, 37.574448241913856],
#       [127.47565866803647, 37.60512112601634],
#       [127.44699730711024, 37.64497584741164],
#       [127.4272349102434, 37.66284420898682],
#       [127.40156700708162, 37.64806970784708],
#       [127.3732642199939, 37.6453987554284],
#       [127.3542931884407, 37.6250006376975],
#       [127.34360057873045, 37.588997440929354],
#       [127.31002843450217, 37.53523876142835],
#       [127.30923294884336, 37.5135706079458],
# ...

# %%
geo01 = json.load(open("경기도행정구역경계.json", encoding="utf-8"))

# %%
geo01
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'code': 31380,
#     'name': '양평군',
#     'name_eng': 'Yangpyeong-gun',
#     'base_year': 2013},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.56113535909492, 37.6256560539258],
#       [127.57290963929243, 37.61087369350498],
#       [127.56366973908277, 37.5842624297699],
#       [127.52226606559191, 37.5828628697518],
#       [127.50048767007603, 37.569036373178626],
#       [127.47687473909174, 37.574448241913856],
#       [127.47565866803647, 37.60512112601634],
#       [127.44699730711024, 37.64497584741164],
#       [127.4272349102434, 37.66284420898682],
#       [127.40156700708162, 37.64806970784708],
#       [127.3732642199939, 37.6453987554284],
#       [127.3542931884407, 37.6250006376975],
#       [127.34360057873045, 37.588997440929354],
#       [127.31002843450217, 37.53523876142835],
#       [127.30923294884336, 37.5135706079458],
# ...

# %%
g_map = folium.Map(location=[37.5502, 126.982], zoom_start=9)

# %%
folium.Choropleth(
    geo_data=geo01
).add_to(g_map)

# %%
df[2017]
# Out:
# 구분
# 수원시장안구     293828
# 수원시권선구     365653
# 수원시팔달구     193311
# 수원시영통구     349836
# 성남시수정구     236932
# 성남시중원구     230366
# 성남시분당구     500212
# 의정부시       441584
# 안양시만안구     254977
# 안양시동안구     332787
# 부천시원미구     442898
# 부천시소사구     222016
# 부천시오정구     184073
# 광명시        332790
# 평택시        481530
# 동두천시        97071
# 안산시상록구     370744
# 안산시단원구     306966
# 고양시덕양구     448684
# 고양시일산동구    293673
# 고양시일산서구    299626
# 과천시         57527
# 구리시        200042
# 남양주시       665321
# 오산시        213437
# 시흥시        419664
# 군포시        281205
# 의왕시        155767
# 하남시        232487
# 용인시처인구     231553
# 용인시기흥구     419429
# 용인시수지구     353099
# 파주시        437848
# 이천시        213142
# 안성시        182786
# 김포시        392092
# 화성시        691086
# 광주시        345947
# 양주시        212146
# 포천시        152925
# 여주시        111984
# 연천군         45431
# 가평군         62973
# 양평군        115105
# Name: 2017, dtype: int64

# %%
folium.Choropleth(
    geo_data=geo01,
    fill_color = "YlOrRd",
    data=df[2017],
    columns=[df.index, df[2017]],
    threshold_scale=[10000, 100000, 300000, 500000, 700000]
).add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Choropleth(
    geo_data=geo01,
    fill_color = "YlOrRd",
    data=df[2017],
    columns=[df.index, df[2017]]
).add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Choropleth(
    geo_data=geo01,
    fill_color = "YlOrRd",
    data=df[2017],
    columns=[df.index, df[2017]],
    threshold_scale=[10000, 100000, 300000, 500000, 700000]
).add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
g_map = folium.Map(location=[37.5502, 126.982], zoom_start=9)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Choropleth(
    geo_data=geo01,
    fill_color = "YlOrRd",
    data=df[2017],
    columns=[df.index, df[2017]],
    fill_opacity = 0.2,
    threshold_scale=[10000, 100000, 300000, 500000, 700000],
    key_on="feature.properties.name"
).add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
g_map = folium.Map(location=[37.5502, 126.982], zoom_start=9)

# %%
folium.Choropleth(
    geo_data=geo01,
    fill_color = "YlOrRd",
    data=df[2017],
    columns=[df.index, df[2017]],
    fill_opacity = 0.1,
    threshold_scale=[10000, 100000, 300000, 500000, 700000],
    key_on="feature.properties.name"
).add_to(g_map)

# %%
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
g_map3 = folium.Map(location=[37.5502, 126.982], zoom_start=9)

# %%
folium.Choropleth(
    geo_data=geo01,
    fill_color = "YlOrRd",
    data=df[2017],
    columns=[df.index, df[2017]],
    fill_opacity = 0.5,
    threshold_scale=[10000, 100000, 300000, 500000, 700000],
    key_on="feature.properties.name"
).add_to(g_map3)

# %%
g_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geo01
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'code': 31380,
#     'name': '양평군',
#     'name_eng': 'Yangpyeong-gun',
#     'base_year': 2013},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.56113535909492, 37.6256560539258],
#       [127.57290963929243, 37.61087369350498],
#       [127.56366973908277, 37.5842624297699],
#       [127.52226606559191, 37.5828628697518],
#       [127.50048767007603, 37.569036373178626],
#       [127.47687473909174, 37.574448241913856],
#       [127.47565866803647, 37.60512112601634],
#       [127.44699730711024, 37.64497584741164],
#       [127.4272349102434, 37.66284420898682],
#       [127.40156700708162, 37.64806970784708],
#       [127.3732642199939, 37.6453987554284],
#       [127.3542931884407, 37.6250006376975],
#       [127.34360057873045, 37.588997440929354],
#       [127.31002843450217, 37.53523876142835],
#       [127.30923294884336, 37.5135706079458],
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-c7111e14e66f> in <module>
# ----> 1 geo01.features
#
# AttributeError: 'dict' object has no attribute 'features'
