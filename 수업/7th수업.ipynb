# %%
import urllib.request

# %%
url = "https://terms.naver.com/imageDetail.nhn?docId=1062053&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2765_000_20%2F20180913194327944_A7SIE118Z.jpg%2F1038.jpg%3Ftype%3Dm4500_4500_fst%26wm%3DN"

# %%
filename = "c:\ai\workspace\python/img01.jpg"

# %%
urllib.request.urlretrieve(url, filename)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-5a5525991153> in <module>
# ----> 1 urllib.request.urlretrieve(url, filename)
#
# C:\ai\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# OSError: [Errno 22] Invalid argument: 'c:\x07i\\workspace\\python/img01.jpg'

# %%
filename = "img01.jpg"

# %%
urllib.request.urlretrieve(url, filename)
# Out:
# ('img01.jpg', <http.client.HTTPMessage at 0x26579be9208>)

# %%
mem = urllib.request.urlopen(url).read()

# %%
mem
# Out:
# b'<html lang="ko">\n<head>\n    <meta charset="utf-8">\n    <title></title>\n    <meta property="og:type" content="article">\n    <meta property="og:url" content="https://terms.naver.com/imageDetail.nhn?cid=40942&docId=1062053&imageUrl=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2765_000_20%2F20180913194327944_A7SIE118Z.jpg%2F1038.jpg%3Ftype%3Dm4500_4500_fst%26wm%3DN&categoryId=32624">\n    <meta property="og:title" content="\xed\x8e\x98\xeb\xa5\xb4\xec\x8b\x9c\xec\x95\x88\xea\xb3\xa0\xec\x96\x91\xec\x9d\xb4 \xec\x9d\xb4\xeb\xaf\xb8\xec\xa7\x80">\n    <meta property="og:image" content="https://dbscthumb-phinf.pstatic.net/2765_000_20/20180913194327944_A7SIE118Z.jpg/1038.jpg?type=r100&wm=N">\n    <meta property="og:description" content="\xec\x88\x9c\xec\x88\x98\xed\x98\x88\xed\x86\xb5\xec\x9d\x98 \xec\x9e\xa5\xeb\xaa\xa8\xec\xa2\x85\xec\x9c\xbc\xeb\xa1\x9c\xec\x84\x9c \xec\x98\xa4\xeb\x9e\x9c \xec\x97\xad\xec\x82\xac\xeb\xa5\xbc \xea\xb0\x80\xec\xa7\x80\xeb\xa9\xb0 \xeb\xaa\xa8\xec\x83
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-c71684493ce4> in <module>
# ----> 1 plt.imshow(mem)
#
# C:\ai\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# C:\ai\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...

# %%
filename = "img02.jpg"

# %%
with open(filename, "wb") as f:
    f.write(mem)

# %%
import io

# %%
io.BytesIO(mem)

# %%
from PIL import Image

# %%
Image.open(io.BytesIO(mem))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-43-b32d9b6ae472> in <module>
# ----> 1 Image.open(io.BytesIO(mem))
#
# C:\ai\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2816     for message in accept_warnings:
#    2817         warnings.warn(message)
# -> 2818     raise IOError("cannot identify image file %r" % (filename if filename else fp))
#    2819
#    2820
#
# OSError: cannot identify image file <_io.BytesIO object at 0x0000026579DAF948>

# %%
import urllib.request

# %%
url = "https://dbscthumb-phinf.pstatic.net/2765_000_20/20180913194327944_A7SIE118Z.jpg/1038.jpg?type=m250&wm=N"

# %%
filename = "img01.jpg"

# %%
urllib.request.urlretrieve(url, filename)
# Out:
# ('img01.jpg', <http.client.HTTPMessage at 0x26579ec5608>)

# %%
mem = urllib.request.urlopen(url).read()
with open(filename, "wb") as f:
    f.write(mem)

# %%
mem
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x00\xaf\x00\xfa\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x02\x02\x03\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x06\x04\x07\x03\x08\x01\x02\t\x00\xff\xc4\x00D\x10\x00\x01\x03\x03\x03\x01\x06\x04\x03\x07\x02\x02\t\x05\x00\x00\x01\x02\x03\x04\x00\x05\x11\x06\x12!1\x07\x13"AQa\x14q\x81\x912B\xa1\x08\x15#R\xb1\xc1\xf0\xd1\xe1$b\x16\x17%35Sr\xb2\xf1c\x8
# ...

# %%
import io

# %%
io.BytesIO(mem)

# %%
from PIL import Image

# %%
Image.open(io.BytesIO(mem))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x175 at 0x26579EB0808>

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "http://192.168.0.61:8089/bs01.html"
response = requests.get(url)

# %%
response.text #그냥 호출하면 글자가 깨짐
# Out:
# '<html>\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n    </head>\r\n\t<body>\r\n\t\t<h1>1</h1>\r\n\t\t<p>2</p>\r\n\t</body>\r\n</html>'

# %%
response.encoding = "UTF-8" #한글로 표시해주는 설정
response.text
# Out:
# '<html>\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n    </head>\r\n\t<body>\r\n\t\t<h1>1</h1>\r\n\t\t<p>2</p>\r\n\t</body>\r\n</html>'

# %%
BeautifulSoup(response.text, "html.parser")
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# </head>
# <body>
# <h1>1</h1>
# <p>2</p>
# </body>
# </html>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.body
# Out:
# <body>
# <h1>1</h1>
# <p>2</p>
# </body>

# %%
b1 = soup.body

# %%
b1
# Out:
# <body>
# <h1>1</h1>
# <p>2</p>
# </body>

# %%
h1 = b1.h1

# %%
h1
# Out:
# <h1>1</h1>

# %%
h1.string
# Out:
# '1'

# %%
soup.body.p
# Out:
# <p>2</p>

# %%
soup.body.p.string
# Out:
# '2'

# %%
url = "http://localhost:8089/bs02.html"

# %%
response = requests.get(url)

# %%
response.encoding = "UTF-8"
response.text
# Out:
# '<html>\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n\t</head>\r\n\t<body>\r\n\t\t<h1 id="title">스크레이핑이란?</h1>\r\n\t\t<p id="body01">웹 페이지를 분석하는 것</p>\r\n\t\t<p id="body02">원 하는 데이터를 추출 하는것</p>\r\n\t</body>\r\n</html>'

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# </head>
# <body>
# <h1 id="title">스크레이핑이란?</h1>
# <p id="body01">웹 페이지를 분석하는 것</p>
# <p id="body02">원 하는 데이터를 추출 하는것</p>
# </body>
# </html>

# %%
soup.find(id = "title")
# Out:
# <h1 id="title">스크레이핑이란?</h1>

# %%
soup.find(id = "title").string
# Out:
# '스크레이핑이란?'

# %%
url = "http://localhost:8089/bs03.html"

# %%
response = requests.get(url)
response.encoding = "UTF-8"
response.text
# Out:
# '<html>\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n\t</head>\r\n\t<body>\r\n\t\t<ul>\r\n\t\t\t<li><a href="http://www.naver.com">naver</a></li>\r\n\t\t\t<li><a href="http://www.daum.net">daum</a></li>\r\n\t\t</ul>\r\n\t</body>\r\n</html>'

# %%
BeautifulSoup(response.text, "html.parser")
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# </head>
# <body>
# <ul>
# <li><a href="http://www.naver.com">naver</a></li>
# <li><a href="http://www.daum.net">daum</a></li>
# </ul>
# </body>
# </html>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.find("a")
# Out:
# <a href="http://www.naver.com">naver</a>

# %%
lst = soup.find_all("a") #리스트 형태

# %%
lst
# Out:
# [<a href="http://www.naver.com">naver</a>,
#  <a href="http://www.daum.net">daum</a>]

# %%
soup
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# </head>
# <body>
# <ul>
# <li><a href="http://www.naver.com">naver</a></li>
# <li><a href="http://www.daum.net">daum</a></li>
# </ul>
# </body>
# </html>

# %%
for e in lst:
    print("e =", e)
    print("e.string =", e.string)
    print("e.attrs =", e.attrs) #dictionary형태
    print("e.attrs[href] =", e.attrs["href"])
# Out:
# e = <a href="http://www.naver.com">naver</a>
# e.string = naver
# e.attrs = {'href': 'http://www.naver.com'}
# e.attrs[href] = http://www.naver.com
# e = <a href="http://www.daum.net">daum</a>
# e.string = daum
# e.attrs = {'href': 'http://www.daum.net'}
# e.attrs[href] = http://www.daum.net
