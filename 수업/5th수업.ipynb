# %%
def power(item):
    print("item =", item)
    return item * item
power(20)
# Out:
# item = 20
# 400

# %%
def under_3(item):
    print("item =", item)
    return item < 3
under_3(1)
# Out:
# item = 1
# True

# %%
power_l = lambda item : item * item
power_l(200)
# Out:
# 40000

# %%
under_3_l = lambda item : item < 3
under_3_l(2)
# Out:
# True

# %%
under_3_l(4)
# Out:
# False

# %%
def print_hello():
    print("안녕하세요")
print_hello()
# Out:
# 안녕하세요

# %%
def call_10_times(func):
    print("call_10_times 시작")
    for i in range(10):
        print("call_10_times: i=", i)
        func()
        print("call_10_times에서 끝")
    
call_10_times(print_hello)
# Out:
# call_10_times 시작
# call_10_times: i= 0
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 1
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 2
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 3
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 4
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 5
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 6
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 7
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 8
# 안녕하세요
# call_10_times에서 끝
# call_10_times: i= 9
# 안녕하세요
# call_10_times에서 끝

# %%
def increase_list(func, input_list):
    output_list = []
    for input in input_list:
        print("input=", input)
        output = func(input)
        print("output=", output)
        output_list.append(output)
        print("output_list=", output_list)
    return output_list

# %%
list_input_a = [1, 2, 3, 4, 5]
increase_list(power, list_input_a)
# Out:
# input= 1
# item = 1
# output= 1
# output_list= [1]
# input= 2
# item = 2
# output= 4
# output_list= [1, 4]
# input= 3
# item = 3
# output= 9
# output_list= [1, 4, 9]
# input= 4
# item = 4
# output= 16
# output_list= [1, 4, 9, 16]
# input= 5
# item = 5
# output= 25
# output_list= [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %%
for input in list_input_a:
    print(input ** 2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
def power_lst(lst):
    for input in lst:
        print(input**2)

# %%
def double_lst(lst):
    for input in lst:
        print(input * 2)

# %%
def increase_list(func, input_lst):
    output_lst = []
    for input in input_lst:
        output = func(input)
        output_list.append(output)
    return output_lst

# %%
list_input_a = [1, 2, 3, 4, 5]

# %%
def power(item):
    return item ** 2

# %%
def condition_list(func, input_list):
    print("input_list =", input_list)
    output_list = []
    for input in input_list:
        print("input = ", input)
        condition = func(input)
        print("condition =", condition)
        if condition == True:
            output_list.append(input)
    return output_list

# %%
list_input_a = [1, 2, 3, 4, 5, 6, 7, 8, 9]
condition_list(lambda item : item < 3, list_input_a)
# Out:
# input_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# input =  1
# condition = True
# input =  2
# condition = True
# input =  3
# condition = False
# input =  4
# condition = False
# input =  5
# condition = False
# input =  6
# condition = False
# input =  7
# condition = False
# input =  8
# condition = False
# input =  9
# condition = False
# [1, 2]

# %%
condition_list(lambda item : item % 3 == 0, list_input_a)
# Out:
# input_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# input =  1
# condition = False
# input =  2
# condition = False
# input =  3
# condition = True
# input =  4
# condition = False
# input =  5
# condition = False
# input =  6
# condition = True
# input =  7
# condition = False
# input =  8
# condition = False
# input =  9
# condition = True
# [3, 6, 9]

# %%
def power(item):
    return item * item
list_input_a = [1, 2, 3]
list(map(power, list_input_a))
# Out:
# [1, 4, 9]

# %%
def under_3(item):
    return item < 3
list_input_a = [1, 2, 3, 4, 5]

# %%
file = open("basic.txt", "w")
file.write("안녕 파이썬 파일!!!")
# Out:
# 12

# %%
file.write("반가워!!!")
file.write("줄 바꾸고 싶다\n")
file.write("바꿔졌네")
file.close()

# %%
with open("basic.txt", "a") as file:
    file.write("안녕 파이썬\n")
    file.write("ㅎ2ㅎ2")

# %%
file = open("basic.txt", "r")
file.read()
# Out:
# '안녕 파이썬 파일!!!반가워!!!줄 바꾸고 싶다\n바꿔졌네안녕 파이썬\nㅎ2ㅎ2'

# %%
file.read()
# Out:
# ''

# %%
file.close()

# %%
import random
num_lst = [1, 2, 3, 4, 5, 6, 7]
hangul_lst = ["가", "나", "다", "라"]

# %%
random.choice(num_lst)
# Out:
# 3

# %%
random.choice(hangul_lst)
# Out:
# '가'

# %%
#1이상 4 미만의 랜덤한 숫자 하나 리턴
random.randrange(1, 4)
# Out:
# 1

# %%
hanguls = list("가나마라마")
random.choice(hanguls) + "^^" + random.choice(hanguls)
with open("실습.txt", "w") as file:
    for i in range(1000):
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40, 100)
        height = random.randrange(140, 200)
        print("{}, {}, {}".format(name, weight, height))
        file.write("{}, {}, {}\n".format(name, weight, height))
        print("=" * 40)
# Out:
# 마마, 59, 166
# ...
# 마마, 51, 192
# ...
# 가마, 60, 178
# ...
# 마가, 59, 198
# ...
# 마마, 60, 193
# ...
# 나마, 84, 167
# ...
# 가가, 51, 152
# ...
# 가나, 93, 197
# ...
# 마마, 50, 182
# ...
# 마나, 46, 191
# ...
# 마마, 80, 159
# ...
# 가마, 90, 175
# ...
# 마마, 96, 147
# ...
# 라마, 98, 158
# ...
# 마나, 45, 194
# ...
# 나나, 58, 154
# ...
# 나가, 95, 193
# ...
# 나라, 72, 153
# ...
# 가라, 71, 183
# ...
# 라라, 99, 188
# ...
# 마가, 78, 176
# ...
# 라마, 87, 157
# ...
# 나나, 67, 165
# ...
# 라라, 73, 175
# ...
# 마마, 68, 143
# ...
# 나마, 50, 185
# ...
# 나마, 81, 161
# ...
# 가가, 95, 147
# ...
# 마마, 53, 196
# ...
# 나마, 98, 195
# ...
# 마라, 87, 142
# ...
# 마마, 63, 164
# ...
# 나마, 47, 194
# ...
# 마가, 71, 148
# ...
# 가마, 99, 148
# ...
# 라라, 58, 175
# ...
# 마라, 48, 170
# ...
# 라나, 43, 145
# ...
# 마마, 75, 175
# ...
# 나라, 67, 157
# ...
# 라라, 46, 189
# ...
# 나가, 64, 145
# ...
# 마나, 83, 153
# ...
# 나마, 47, 184
# ...
# 가나, 50, 164
# ...
# 라가, 68, 166
# ...
# 마라, 49, 174
# ...
# 나나, 74, 165
# ...
# 나가, 63, 182
# ...
# 가라, 51, 152
# ...
# 가나, 58, 160
# ...
# 가마, 82, 171
# ...
# 라가, 76, 142
# ...
# 나마, 93, 159
# ...
# 가마, 97, 193
# ...
# 마가, 96, 142
# ...
# 마마, 40, 150
# ...
# 나가, 46, 181
# ...
# 라마, 88, 140
# ...
# 나마, 59, 146
# ...
# 라마, 57, 176
# ...
# 라가, 78, 175
# ...
# 가나, 45, 160
# ...
# 마나, 80, 145
# ...
# 마마, 87, 155
# ...
# 가나, 65, 140
# ...
# 가마, 50, 177
# ...
# 마가, 73, 193
# ...
# 라나, 40, 186
# ...
# 마마, 40, 145
# ...
# 마나, 66, 179
# ...

# %%
line = "     안녕     "
line
# Out:
# '     안녕     '

# %%
line.strip()
# Out:
# '안녕'

# %%
line = "길동, 87, 170"
line.split(".")
# Out:
# ['길동, 87, 170']

# %%
line = "길동, 87, "

# %%
name, weight, height = "길동, 87, 170".split(",")

# %%
name
# Out:
# '길동'

# %%
weight
# Out:
# ' 87'

# %%
height
# Out:
# ' 170'

# %%
bmi = int(weight) / ((int(height) / 100) ** 2)

# %%
bmi
# Out:
# 30.103806228373706

# %%
with open("실습.txt", "r") as file:
    content = file.read()

# %%
with open("실습.txt", "r") as file:
    for line in file:
        print("line:", line)
# Out:
# line: 마마, 59, 166
#
# line: 마마, 51, 192
#
# line: 가마, 60, 178
#
# line: 마가, 59, 198
#
# line: 마마, 60, 193
#
# line: 나마, 84, 167
#
# line: 가가, 51, 152
#
# line: 가나, 93, 197
#
# line: 마마, 50, 182
#
# line: 마나, 46, 191
#
# line: 마마, 80, 159
#
# line: 가마, 90, 175
#
# line: 마마, 96, 147
#
# line: 라마, 98, 158
#
# line: 마나, 45, 194
#
# line: 나나, 58, 154
#
# line: 나가, 95, 193
#
# line: 나라, 72, 153
#
# line: 가라, 71, 183
#
# line: 라라, 99, 188
#
# line: 마가, 78, 176
#
# line: 라마, 87, 157
#
# line: 나나, 67, 165
#
# line: 라라, 73, 175
#
# line: 마마, 68, 143
#
# line: 나마, 50, 185
#
# line: 나마, 81, 161
#
# line: 가가, 95, 147
#
# line: 마마, 53, 196
#
# line: 나마, 98, 195
#
# line: 마라, 87, 142
#
# line: 마마, 63, 164
#
# line: 나마, 47, 194
#
# line: 마가, 71, 148
#
# line: 가마, 99, 148
#
# line: 라라, 58, 175
#
# line: 마라, 48, 170
#
# line: 라나, 43, 145
#
# line: 마마, 75, 175
#
# line: 나라, 67, 157
#
# line: 라라, 46, 189
#
# line: 나가, 64, 145
#
# line: 마나, 83, 153
#
# line: 나마, 47, 184
#
# line: 가나, 50, 164
#
# ...

# %%
str_list = ["길동", "영희", "철수", "몽룡"]
"^^".join(str_list)
# Out:
# '길동^^영희^^철수^^몽룡'

# %%
numbers = [1, 2, 3]
"::".join(numbers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-e8261455f2bb> in <module>
#       1 numbers = [1, 2, 3]
# ----> 2 "::".join(numbers)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
map(str, numbers)

# %%
list(map(str, numbers))
# Out:
# ['1', '2', '3']

# %%
"::"
