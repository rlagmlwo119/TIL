# %%
import pandas as pd

# %%
A = pd.DataFrame({"sal": [1200, 1600, 5600, 6000, 7000]})

# %%
A
# Out:
#     sal
# 0  1200
# 1  1600
# 2  5600
# 3  6000
# 4  7000

# %%
A.mean()
# Out:
# sal    4280.0
# dtype: float64

# %%
A - A.mean()
# Out:
#       sal
# 0 -3080.0
# 1 -2680.0
# 2  1320.0
# 3  1720.0
# 4  2720.0

# %%
B = pd.DataFrame({"sal": [4000, 4500, 4250, 5000, 3650]})

# %%
B
# Out:
#     sal
# 0  4000
# 1  4500
# 2  4250
# 3  5000
# 4  3650

# %%
B.mean()
# Out:
# sal    4280.0
# dtype: float64

# %%
B-B.mean()
# Out:
#      sal
# 0 -280.0
# 1  220.0
# 2  -30.0
# 3  720.0
# 4 -630.0

# %%
import math

# %%
((A - A.mean()) ** 2).sum() / 4
# Out:
# sal    7192000.0
# dtype: float64

# %%
A.var()
# Out:
# sal    7192000.0
# dtype: float64

# %%
((B-B.mean())**2).sum() / 4
# Out:
# sal    260750.0
# dtype: float64

# %%
B.var()
# Out:
# sal    260750.0
# dtype: float64

# %%
A.var() > B.var()
# Out:
# sal    True
# dtype: bool

# %%
math.sqrt(A.var())
# Out:
# 2681.790446697877

# %%
math.sqrt(B.var())
# Out:
# 510.63685726747144

# %%
A.std()
# Out:
# sal    2681.790447
# dtype: float64

# %%
B.std()
# Out:
# sal    510.636857
# dtype: float64

# %%
df01 = pd.DataFrame({"eng_rank": [1, 4, 2, 9, 9], "kor_rank": [3, 2, 7, 3, 10]})

# %%
eng_mean = df01["eng_rank"].mean()

# %%
kor_mean = df01["kor_rank"].mean()

# %%
eng_mean
# Out:
# 5.0

# %%
kor_mean
# Out:
# 5.0

# %%
eng_sub = df01["eng_rank"] - eng_mean

# %%
eng_sub
# Out:
# 0   -4.0
# 1   -1.0
# 2   -3.0
# 3    4.0
# 4    4.0
# Name: eng_rank, dtype: float64

# %%
kor_sub = df01["kor_rank"] - kor_mean

# %%
kor_sub
# Out:
# 0   -2.0
# 1   -3.0
# 2    2.0
# 3   -2.0
# 4    5.0
# Name: kor_rank, dtype: float64

# %%
sum(eng_sub * kor_sub) / 4
# Out:
# 4.25

# %%
df01.cov()
# Out:
#           eng_rank  kor_rank
# eng_rank     14.50      4.25
# kor_rank      4.25     11.50

# %%
df01["eng_rank"].std()
# Out:
# 3.8078865529319543

# %%
df01["kor_rank"].std()
# Out:
# 3.391164991562634

# %%
df01.cov()/(df01["eng_rank"].std() * df01["kor_rank"].std())
# Out:
#           eng_rank  kor_rank
# eng_rank  1.122884  0.329121
# kor_rank  0.329121  0.890564

# %%
df01.corr()
# Out:
#           eng_rank  kor_rank
# eng_rank  1.000000  0.329121
# kor_rank  0.329121  1.000000

# %%
df = pd.read_csv("auto-mpg.csv")

# %%
df.columns = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "name"]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5          70
# 1  18.0          8         318.0      150.0  3436.0          11.0          70
# 2  16.0          8         304.0      150.0  3433.0          12.0          70
# 3  17.0          8         302.0      140.0  3449.0          10.5          70
# 4  15.0          8         429.0      198.0  4341.0          10.0          70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 392  27.0          4         140.0      86.00  2790.0          15.6
# 393  44.0          4          97.0      52.00  2130.0          24.6
# 394  32.0          4         135.0      84.00  2295.0          11.6
# 395  28.0          4         120.0      79.00  2625.0          18.6
# 396  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin             name
# 392          82       1  ford mustang gl
# 393          82       2        vw pickup
# 394          82       1    dodge rampage
# 395          82       1      ford ranger
# 396          82       1       chevy s-10

# %%
df.shape
# Out:
# (397, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
# mpg             397 non-null float64
# cylinders       397 non-null int64
# displacement    397 non-null float64
# horsepower      397 non-null object
# weight          397 non-null float64
# acceleration    397 non-null float64
# model year      397 non-null int64
# origin          397 non-null int64
# name            397 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.0+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.528463    5.448363    193.139798  2969.080605     15.577078
# std      7.820926    1.698329    104.244898   847.485218      2.755326
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.900000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.200000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  397.000000  397.000000
# mean    76.025189    1.574307
# std      3.689922    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(include="all")
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   397.000000  397.000000    397.000000        397   397.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.528463    5.448363    193.139798        NaN  2969.080605
# std       7.820926    1.698329    104.244898        NaN   847.485218
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.000000        NaN  2223.000000
# 50%      23.000000    4.000000    146.000000        NaN  2800.000000
# 75%      29.000000    8.000000    262.000000        NaN  3609.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin        name
# count     397.000000  397.000000  397.000000         397
# ...

# %%
df.count()
# Out:
# mpg             397
# cylinders       397
# displacement    397
# horsepower      397
# weight          397
# acceleration    397
# model year      397
# origin          397
# name            397
# dtype: int64

# %%
unique_values = df["origin"].value_counts()

# %%
unique_values
# Out:
# 1    248
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
type(unique_values)
# Out:
# pandas.core.series.Series

# %%
df.mean()
# Out:
# mpg               23.528463
# cylinders          5.448363
# displacement     193.139798
# weight          2969.080605
# acceleration      15.577078
# model year        76.025189
# origin             1.574307
# dtype: float64

# %%
df["mpg"].mean()
# Out:
# 23.528463476070538

# %%
df.mpg.mean()
# Out:
# 23.528463476070538

# %%
df[["mpg", "weight"]].mean()
# Out:
# mpg         23.528463
# weight    2969.080605
# dtype: float64

# %%
df.median()
# Out:
# mpg               23.0
# cylinders          4.0
# displacement     146.0
# weight          2800.0
# acceleration      15.5
# model year        76.0
# origin             1.0
# dtype: float64

# %%
df["mpg"].median()
# Out:
# 23.0

# %%
df.max()
# Out:
# mpg                         46.6
# cylinders                      8
# displacement                 455
# horsepower                     ?
# weight                      5140
# acceleration                24.8
# model year                    82
# origin                         3
# name            vw rabbit custom
# dtype: object

# %%
df["mpg"].max()
# Out:
# 46.6

# %%
df.min()
# Out:
# mpg                                   9
# cylinders                             3
# displacement                         68
# horsepower                        100.0
# weight                             1613
# acceleration                          8
# model year                           70
# origin                                1
# name            amc ambassador brougham
# dtype: object

# %%
df["mpg"].min()
# Out:
# 9.0

# %%
df.std()
# Out:
# mpg               7.820926
# cylinders         1.698329
# displacement    104.244898
# weight          847.485218
# acceleration      2.755326
# model year        3.689922
# origin            0.802549
# dtype: float64

# %%
df["mpg"].std()
# Out:
# 7.820926403236991

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775412     -0.803972 -0.831558      0.419133
# cylinders    -0.775412   1.000000      0.950718  0.896623     -0.503016
# displacement -0.803972   0.950718      1.000000  0.932957     -0.542083
# weight       -0.831558   0.896623      0.932957  1.000000     -0.416488
# acceleration  0.419133  -0.503016     -0.542083 -0.416488      1.000000
# model year    0.578667  -0.344729     -0.367470 -0.305150      0.284376
# origin        0.562894  -0.561796     -0.608749 -0.580552      0.204102
#
#               model year    origin
# mpg             0.578667  0.562894
# cylinders      -0.344729 -0.561796
# displacement   -0.367470 -0.608749
# weight         -0.305150 -0.580552
# acceleration    0.284376  0.204102
# model year      1.000000  0.178441
# origin          0.178441  1.000000

# %%
df[["mpg", "weight"]].corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.831558
# weight -0.831558  1.000000

# %%
df = pd.read_excel("남북한발전전력량.xlsx")

# %%
df_ns = df.iloc[[0, 5], 3: ]

# %%
df_ns.index = ["South", "North"]

# %%
df_ns.columns = df_ns.columns.map(int)

# %%
df_ns.plot()

# %%
df_ns.plot()

# %%
tdf_ns = df_ns.T

# %%
tdf_ns
# Out:
#      South North
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
tdf_ns.plot()

# %%
tdf_ns.plot(kind="bar")

# %%
tdf_ns.plot(kind="hist")

# %%
df = pd.read_csv("auto-mpg.csv")

# %%
df.columns = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "name"]

# %%
df.plot(x="weight", y="mpg", kind="scatter")

# %%
df[["mpg", "cylinders"]].plot(kind="box")

# %%
CCTV_Seoul = pd.read_csv("CCTV_in_Seoul.csv", encoding="utf-8")

# %%
CCTV_Seoul
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:"구별"}, inplace=True)

# %%
CCTV_Seoul
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls", encoding="utf-8")

# %%
pop_Seoul
# Out:
#           기간   자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0         기간   자치구       세대        합계       합계       합계      한국인      한국인
# 1         기간   자치구       세대         계       남자       여자        계       남자
# 2   2017.1/4    합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3   2017.1/4   종로구    72654    162820    79675    83145   153589    75611
# 4   2017.1/4    중구    59481    133240    65790    67450   124312    61656
# 5   2017.1/4   용산구   106544    244203   119132   125071   229456   111167
# 6   2017.1/4   성동구   130868    311244   153768   157476   303380   150076
# 7   2017.1/4   광진구   158960    372164   180992   191172   357211   174599
# 8   2017.1/4  동대문구   159839    369496   182932   186564   354079   177021
# 9   2017.1/4   중랑구   177548    414503   206102   208401   409882   204265
# 10  2017.1/4   성북구   188512    461260   224076   237184   449773   219545
# 11  2017.1/4   강북구   141554    330192   161686   168506   326686   160353
# ...

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls", header=2, encoding="utf-8")

# %%
pop_Seoul
# Out:
#           기간   자치구         세대           계         남자         여자        계.1  \
# 0   2017.1/4    합계  4202888.0  10197604.0  5000005.0  5197599.0  9926968.0
# 1   2017.1/4   종로구    72654.0    162820.0    79675.0    83145.0   153589.0
# 2   2017.1/4    중구    59481.0    133240.0    65790.0    67450.0   124312.0
# 3   2017.1/4   용산구   106544.0    244203.0   119132.0   125071.0   229456.0
# 4   2017.1/4   성동구   130868.0    311244.0   153768.0   157476.0   303380.0
# 5   2017.1/4   광진구   158960.0    372164.0   180992.0   191172.0   357211.0
# 6   2017.1/4  동대문구   159839.0    369496.0   182932.0   186564.0   354079.0
# 7   2017.1/4   중랑구   177548.0    414503.0   206102.0   208401.0   409882.0
# 8   2017.1/4   성북구   188512.0    461260.0   224076.0   237184.0   449773.0
# 9   2017.1/4   강북구   141554.0    330192.0   161686.0   168506.0   326686.0
# 10  2017.1/4   도봉구   136613.0    348646.0   171026.0   177620.0   346629.0
# ...

# %%
pop_Seoul = pd.read_excel("population_in_Seoul.xls",
                          header=2,
                          encoding="utf-8",
                         usecols = "B, D, G, J, N"
                         )

# %%
pop_Seoul
# Out:
#      자치구           계        계.1       계.2   65세이상고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_Seoul.columns = ["구별", "인구수", "한국인", "외국인", "고령자"]

# %%
pop_Seoul
# Out:
#       구별         인구수        한국인       외국인        고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_Seoul.drop([0], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-667ed8cdbc81> in <module>
# ----> 1 pop_Seoul.drop([0], inplace=True)
#
# C:\ai\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ai\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\ai\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul.drop([26], inplace=True)

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul["외국인비율"] = pop_Seoul["외국인"] / pop_Seoul["인구수"] * 100
pop_Seoul["고령자비율"] = pop_Seoul["고령자"] / pop_Seoul["인구수"] * 100

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4    성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5    광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 6   동대문구  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322
# 7    중랑구  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 8    성북구  461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 10   도봉구  348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 11   노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 12   은평구  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797
# ...

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on="구별")

# %%
data_result
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       인구수       한국인      외국인  \
# 0    강남구  2780       1292    430    584    932  570500.0  565550.0   4950.0
# 1    강동구   773        379     99    155    377  453233.0  449019.0   4214.0
# 2    강북구   748        369    120    138    204  330192.0  326686.0   3506.0
# 3    강서구   884        388    258    184     81  603772.0  597248.0   6524.0
# 4    관악구  1496        846    260    390    613  525515.0  507203.0  18312.0
# 5    광진구   707        573     78     53    174  372164.0  357211.0  14953.0
# 6    구로구  1561       1142    173    246    323  447874.0  416487.0  31387.0
# 7    금천구  1015        674     51    269    354  255082.0  236353.0  18729.0
# 8    노원구  1265        542     57    451    516  569384.0  565565.0   3819.0
# 9    도봉구   485        238    159     42    386  348646.0  346629.0   2017.0
# 10  동대문구  1294       1070     23    198    579  369496.0  354079.0  15417.0
# ...

# %%
import platform
import matplotlib.pyplot as plt

# %%
plt.rc("font", family="Malgun Gothic")

# %%
data_result["고령자비율"].plot(kind="barh")

# %%
data_result = data_result.set_index("구별")

# %%
data_result["고령자비율"].plot(kind="barh")

# %%
data_result["고령자비율"].plot(kind="barh", figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="barh", figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(marker="o", markersize=10, figsize=(10,5))

# %%
plt.style.use("ggplot")

# %%
data_result["고령자비율"].sort_values().plot(kind="area", stacked=False, figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="bar", figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="barh",  figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="bar", color="cornflowerblue",
                                        figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="barh", color="cornflowerblue",
                                        figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="hist", color="cornflowerblue",
                                        figsize=(10,5))

# %%
data_result.plot(kind="scatter", 
                 x = "고령자비율", 
                 y="외국인비율",
                 color="cornflowerblue",
                 figsize=(10,5)
                )

# %%
data_result.plot(kind="scatter", 
                 x = "인구수", 
                 y="소계",
                 color="cornflowerblue",
                 figsize=(10,5)
                )

# %%
data_result["고령자비율"].sort_values().plot(kind="bar",
                                        color="cornflowerblue",
                                        figsize=(10,5))

# %%
data_result["고령자비율"].sort_values(ascending=True).plot(
    kind="bar",
    color="cornflowerblue", 
    figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(kind="barh", color="cornflowerblue",
                                        figsize=(10,5))

# %%
data_result["고령자비율"].sort_values().plot(marker="x", 
                                        markersize=10, 
                                        color="cornflowerblue",
                                        figsize=(10, 5))
